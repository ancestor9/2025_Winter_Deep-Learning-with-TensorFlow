# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/2025_Winter_Deep-Learning-with-TensorFlow/blob/main/20260107_03_Image%20Classification/keras_cifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We'll download the dataset first:

# %% [markdown]
# https://www.packtpub.com/en-us/product/python-deep-learning-9781837638505

# %%
import tensorflow as tf

(X_train, Y_train), (X_validation, Y_validation) = \
    tf.keras.datasets.cifar10.load_data()

Y_train = tf.keras.utils.to_categorical(Y_train, 10)
Y_validation = tf.keras.utils.to_categorical(Y_validation, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# Next, we'll instantiate a DataGenerator, which will normalize the train and test datasets, and will provide data augmentation during training:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_generator = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    horizontal_flip=True,
    vertical_flip=True)

# Apply z-normalization on the training set
data_generator.fit(X_train)

# Standardize the validation set
X_validation = data_generator.standardize(X_validation.astype('float32'))

# %% [markdown]
# Then, we'll define the CNN model:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, BatchNormalization, Activation, Flatten

model = Sequential(layers=[
    Conv2D(32, (3, 3),
           padding='same',
           input_shape=X_train.shape[1:]),
    BatchNormalization(),
    Activation('gelu'),
    Conv2D(32, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('gelu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.2),

    Conv2D(64, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('gelu'),
    Conv2D(64, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('gelu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),

    Conv2D(128, (3, 3)),
    BatchNormalization(),
    Activation('gelu'),
    Conv2D(128, (3, 3)),
    BatchNormalization(),
    Activation('gelu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.5),

    Flatten(),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# We'll define the optimization parameters:

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 293,930 (1.12 MB)
#  Trainable params: 293,034 (1.12 MB)
#  Non-trainable params: 896 (3.50 KB)
# None

# %% [markdown]
# Finally, we'll run the training and evaluation:

# %%
batch_size = 50

model.fit(
    x=data_generator.flow(x=X_train,
                          y=Y_train,
                          batch_size=batch_size),
    steps_per_epoch=len(X_train) // batch_size,
    epochs=100,
    verbose=1,
    validation_data=(X_validation, Y_validation)
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 12ms/step - accuracy: 0.3192 - loss: 2.0131 - val_accuracy: 0.5552 - val_loss: 1.2439
# Epoch 2/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5468 - loss: 1.2445 - val_accuracy: 0.6196 - val_loss: 1.0792
# Epoch 3/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6189 - loss: 1.0590 - val_accuracy: 0.6635 - val_loss: 0.9475
# Epoch 4/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6604 - loss: 0.9490 - val_accuracy: 0.6963 - val_loss: 0.8366
# Epoch 5/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6847 - loss: 0.8861 - val_accuracy: 0.7129 - val_loss: 0.8056
# Epoch 6/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7062 - loss: 0.8245 - val_accuracy: 0.7206 - val_loss: 0.7937
# Epoch 7/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7201 - loss: 0.7958 - val_accuracy: 0.7485 - val_loss: 0.6939
# Epoch 8/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7339 - loss: 0.7487 - val_accuracy: 0.7464 - val_loss: 0.7011
# Epoch 9/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7462 - loss: 0.7181 - val_accuracy: 0.7643 - val_loss: 0.6671
# Epoch 10/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7561 - loss: 0.6868 - val_accuracy: 0.7659 - val_loss: 0.6582
# Epoch 11/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7649 - loss: 0.6731 - val_accuracy: 0.7836 - val_loss: 0.6099
# Epoch 12/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7702 - loss: 0.6523 - val_accuracy: 0.7555 - val_loss: 0.7065
# Epoch 13/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7736 - loss: 0.6446 - val_accuracy: 0.7911 - val_loss: 0.5953
# Epoch 14/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7825 - loss: 0.6193 - val_accuracy: 0.7929 - val_loss: 0.5899
# Epoch 15/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7875 - loss: 0.6048 - val_accuracy: 0.7903 - val_loss: 0.5946
# Epoch 16/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7856 - loss: 0.6027 - val_accuracy: 0.8035 - val_loss: 0.5673
# Epoch 17/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7974 - loss: 0.5742 - val_accuracy: 0.8076 - val_loss: 0.5535
# Epoch 18/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7987 - loss: 0.5718 - val_accuracy: 0.8106 - val_loss: 0.5384
# Epoch 19/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.7960 - loss: 0.5716 - val_accuracy: 0.8138 - val_loss: 0.5310
# Epoch 20/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8080 - loss: 0.5418 - val_accuracy: 0.8170 - val_loss: 0.5218
# Epoch 21/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8087 - loss: 0.5502 - val_accuracy: 0.8090 - val_loss: 0.5563
# Epoch 22/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8151 - loss: 0.5338 - val_accuracy: 0.8159 - val_loss: 0.5362
# Epoch 23/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8174 - loss: 0.5275 - val_accuracy: 0.8206 - val_loss: 0.5156
# Epoch 24/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8170 - loss: 0.5179 - val_accuracy: 0.8176 - val_loss: 0.5328
# Epoch 25/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8170 - loss: 0.5199 - val_accuracy: 0.8320 - val_loss: 0.4831
# Epoch 26/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8219 - loss: 0.5073 - val_accuracy: 0.8293 - val_loss: 0.4922
# Epoch 27/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8219 - loss: 0.5076 - val_accuracy: 0.8382 - val_loss: 0.4726
# Epoch 28/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8236 - loss: 0.5020 - val_accuracy: 0.8327 - val_loss: 0.4718
# Epoch 29/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8288 - loss: 0.4906 - val_accuracy: 0.8331 - val_loss: 0.4842
# Epoch 30/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8284 - loss: 0.4856 - val_accuracy: 0.8316 - val_loss: 0.4901
# Epoch 31/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8340 - loss: 0.4785 - val_accuracy: 0.8332 - val_loss: 0.4686
# Epoch 32/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8315 - loss: 0.4787 - val_accuracy: 0.8323 - val_loss: 0.4827
# Epoch 33/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8331 - loss: 0.4734 - val_accuracy: 0.8268 - val_loss: 0.4994
# Epoch 34/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8343 - loss: 0.4675 - val_accuracy: 0.8386 - val_loss: 0.4646
# Epoch 35/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8389 - loss: 0.4619 - val_accuracy: 0.8451 - val_loss: 0.4554
# Epoch 36/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.8382 - loss: 0.4604 - val_accuracy: 0.8473 - val_loss: 0.4494
# Epoch 37/100
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8401 - loss: 0.4580 - val_accuracy: 0.8339 - val_loss: 0.4796
# Epoch 38/100
#  335/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8382 - loss: 0.4406
